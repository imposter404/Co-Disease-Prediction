# %%
import pandas as pd 
import numpy as np
from sklearn import tree
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
import os
import array
import warnings
from sklearn.metrics import ( 
    accuracy_score, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    f1_score, 
    classification_report, 
)
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
os.system('cls')
# Out:
# 0

# %%
df = pd.read_csv("Training.csv")
test=""
symptom=['itching','skin_rash','nodal_skin_eruptions']
symptom=list(set(symptom))
disease=set(df['prognosis'])
disease=list(disease)
disease.sort()
feature_cols =list(df.columns)
feature_cols.pop()

# -------------------------
X = df[feature_cols] 
y = list(df['prognosis'])
y = pd.get_dummies(y,drop_first=False)
y_col=y.columns.to_list()
# -------------------------

# %%
def patient():
    global test
    patient_data = pd.read_csv("b3_binary.csv")
    patient_data=patient_data.drop("prognosis", axis=1)
    # x=patient_data.iloc[0]
    # print(tuple(patient_data))
    # print(x[0])
    test=patient_data
patient()

# %%
decisionTree_final=[]
RandomForest_final=[]
# Bays_final=[]
svm_final=[]

multi_output_tree=""
multi_output_svm=""
multi_output_Forest=""

# %%
def disease_output(e,f):
    global y_col

    for i in range(len(e)):
        temp=[]
        for j in range(len(e[0])):
            if(e[i][j]==True):
                temp.append(y_col[j])
        f.append(temp)

# %%
def SVM():
    global multi_output_svm
    global X,y
    global svm_final
    svm_final=[]
    clf = svm.SVC(kernel='linear')
    multi_output_svm=MultiOutputClassifier(clf)
    multi_output_svm.fit(X, y)
    
def SVM_outpt():
    global test
    global multi_output_svm
    global svm_final
    predict= multi_output_svm.predict(test)
    disease_output(predict,svm_final)

# %%
def decisionTree():
    global multi_output_tree
    global X,y
    global decisionTree_final
    decisionTree_final=[]
    dtree = DecisionTreeClassifier() 
    multi_output_tree=MultiOutputClassifier(dtree)
    multi_output_tree.fit(X,y) 

def decisionTree_Output():
    global test
    global multi_output_tree
    global decisionTree_final
    predict = multi_output_tree.predict(test)
    disease_output(predict,decisionTree_final)

# %%
def RandomForest():
    global multi_output_Forest
    global X,y
    rf = RandomForestClassifier()
    # multi_output_Forest=rf
    multi_output_Forest=MultiOutputClassifier(rf)
    multi_output_Forest.fit(X,y) 

    # param_dist = {'n_estimators': randint(1,50), 'max_depth': randint(1,50)}
    # rf = RandomForestClassifier()
    # rand_search = RandomizedSearchCV(rf, param_distributions = param_dist, n_iter=10, cv=5)
    # rand_search.fit(X, y)
    # multi_output_Forest=MultiOutputClassifier(rand_search.best_estimator_)
    # # multi_output_Forest=rand_search.best_estimator_
    # multi_output_Forest.fit(X,y)
    # print(multi_output_Forest)

# RandomForest()

# %%
def RandomForest_Output():
    global test
    global multi_output_Forest
    global RandomForest_final
    RandomForest_final=[]
    predict = multi_output_Forest.predict(test)
    disease_output(predict,RandomForest_final)

# %%
decisionTree()
decisionTree_Output()
RandomForest()
RandomForest_Output()
SVM()
SVM_outpt()

# %%
import json

with open('b_pair.json','r') as openfile:
    pair=json.load(openfile)

# %%
r=0
d=0
s=0
def Final():
    global r,d,s
    r=0
    d=0
    s=0
    for i in range(len(RandomForest_final)):
        # print("decisionTree:",decisionTree_final[i])
        # print("RandomForest:",RandomForest_final[i])
        # print("svm:         ",svm_final[i],i)
        # print("pair:        ",  pair[i])
        # print('\n')

        if (len(decisionTree_final[i])>=len(pair[i])):
            d=d+1
        # else :
        #     print("decisionTree:",decisionTree_final[i])
        #     print("RandomForest:",RandomForest_final[i])
        #     print("svm:         ",svm_final[i],i)
        #     print("pair:        ",  pair[i])
        #     print('d \n')

        if (len(RandomForest_final[i])>=len(pair[i])):
            r=r+1
        else :
            # print("decisionTree:",decisionTree_final[i])
            print("RandomForest:",RandomForest_final[i])
            # print("svm:         ",svm_final[i],i)
            print("pair:        ",  pair[i])
            print('r \n')

        if (len(svm_final[i])>=len(pair[i])):
            s=s+1
        # else :
        #     print("decisionTree:",decisionTree_final[i])
        #     print("RandomForest:",RandomForest_final[i])
        #     print("svm:         ",svm_final[i],i)
        #     print("pair:        ",  pair[i])
        #     print('s \n')
Final()
print('r',r,'d',d,'s',s)
# Out:
# RandomForest: []
# pair:         ['Chronic cholestasis', 'Pneumonia', 'hepatitis A']
# r
#
# RandomForest: ['Diabetes', 'Hypoglycemia']
# pair:         ['Chronic cholestasis', 'Drug Reaction', 'Fungal infection']
# r
#
# RandomForest: ['Hypoglycemia']
# pair:         ['Hepatitis D', 'Pneumonia', 'Tuberculosis']
# r
#
# RandomForest: []
# pair:         ['Cervical spondylosis', 'Varicose veins']
# r
#
# RandomForest: ['Hepatitis E']
# pair:         ['Impetigo', 'Psoriasis']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['Dengue', 'Jaundice']
# r
#
# RandomForest: ['Common Cold']
# pair:         ['Arthritis', 'Hypertension', 'Migraine']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['Alcoholic hepatitis', 'Hypothyroidism', 'Paralysis (brain hemorrhage)']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['Peptic ulcer diseae', 'hepatitis A', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Hepatitis E']
# pair:         ['Cervical spondylosis', 'Hepatitis E', 'Urinary tract infection']
# r
#
# RandomForest: ['Jaundice']
# pair:         ['Chicken pox', 'Paralysis (brain hemorrhage)']
# r
#
# RandomForest: ['Malaria', 'Varicose veins']
# pair:         ['Common Cold', 'Drug Reaction', 'Hepatitis B']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['Heart attack', 'hepatitis A']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['Bronchial Asthma', 'Impetigo']
# r
#
# RandomForest: ['Hyperthyroidism', 'Typhoid']
# pair:         ['Dimorphic hemmorhoids(piles)', 'Drug Reaction', 'Urinary tract infection']
# r
#
# RandomForest: ['Hepatitis E']
# pair:         ['Hepatitis C', 'Hepatitis D', 'Hypoglycemia']
# r
#
# RandomForest: ['hepatitis A']
# pair:         ['Arthritis', 'GERD', 'Jaundice']
# r
#
# RandomForest: ['Dimorphic hemmorhoids(piles)', 'vertigo Paroymsal  Positional Vertigo']
# pair:         ['Bronchial Asthma', 'Diabetes', 'Drug Reaction']
# r
#
# RandomForest: ['Dengue']
# pair:         ['Cervical spondylosis', 'Drug Reaction', 'Hyperthyroidism']
# r
#
# RandomForest: ['Chronic cholestasis']
# pair:         ['Chronic cholestasis', 'Hypertension', 'Impetigo']
# r
#
# RandomForest: ['Dimorphic hemmorhoids(piles)', 'Hypothyroidism']
# pair:         ['Drug Reaction', 'Osteoarthristis', 'Typhoid']
# r
#
# RandomForest: ['Hepatitis B']
# pair:         ['Psoriasis', 'Varicose veins', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Hepatitis D', 'Hypothyroidism']
# pair:         ['AIDS', 'Malaria', 'Varicose veins']
# r
#
# RandomForest: ['Common Cold']
# pair:         ['Acne', 'Impetigo', 'Paralysis (brain hemorrhage)']
# r
#
# RandomForest: ['Pneumonia']
# pair:         ['Bronchial Asthma', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Dengue']
# pair:         ['Arthritis', 'Hypoglycemia']
# r
#
# RandomForest: ['Jaundice']
# pair:         ['Arthritis', 'Psoriasis']
# r
#
# RandomForest: []
# pair:         ['Alcoholic hepatitis', 'Allergy', 'Arthritis']
# r
#
# RandomForest: ['Common Cold']
# pair:         ['Cervical spondylosis', 'GERD', 'Urinary tract infection']
# r
#
# RandomForest: ['Hepatitis E']
# pair:         ['Allergy', 'Hepatitis E']
# r
#
# RandomForest: ['Dengue', 'Migraine']
# pair:         ['Chicken pox', 'Hypoglycemia', 'Impetigo']
# r
#
# RandomForest: ['Diabetes']
# pair:         ['Alcoholic hepatitis', 'Pneumonia']
# r
#
# RandomForest: ['Hepatitis E']
# pair:         ['Hypothyroidism', 'Jaundice', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Common Cold']
# pair:         ['Drug Reaction', 'Hypothyroidism', 'Urinary tract infection']
# r
#
# RandomForest: ['Dengue', 'Hypothyroidism']
# pair:         ['Malaria', 'Urinary tract infection', 'hepatitis A']
# r
#
# RandomForest: ['Hepatitis C', 'Hypertension']
# pair:         ['Fungal infection', 'Gastroenteritis', 'Psoriasis']
# r
#
# RandomForest: ['Common Cold', 'Dengue']
# pair:         ['Drug Reaction', 'Hypoglycemia', 'Osteoarthristis']
# r
#
# RandomForest: ['Dimorphic hemmorhoids(piles)', 'Urinary tract infection']
# pair:         ['Cervical spondylosis', 'Hepatitis C', 'Urinary tract infection']
# r
#
# RandomForest: ['Typhoid']
# pair:         ['Hypoglycemia', 'hepatitis A']
# r
#
# RandomForest: ['Chicken pox']
# pair:         ['AIDS', 'Chicken pox', 'GERD']
# r
#
# RandomForest: ['Hyperthyroidism']
# pair:         ['Alcoholic hepatitis', 'Hepatitis D']
# r
#
# RandomForest: ['AIDS', 'Urinary tract infection']
# pair:         ['Arthritis', 'Cervical spondylosis', 'Urinary tract infection']
# r
#
# RandomForest: ['Jaundice']
# pair:         ['Migraine', 'Peptic ulcer diseae']
# r
#
# RandomForest: ['Hypoglycemia']
# pair:         ['Hepatitis D', 'Pneumonia']
# r
#
# RandomForest: ['Peptic ulcer diseae']
# pair:         ['Arthritis', 'Pneumonia']
# r
#
# RandomForest: ['Dengue']
# pair:         ['Hepatitis B', 'Jaundice', 'Psoriasis']
# r
#
# RandomForest: ['Hepatitis D']
# pair:         ['Allergy', 'Psoriasis']
# r
#
# RandomForest: ['Hepatitis D']
# pair:         ['Fungal infection', 'Tuberculosis', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Dengue', 'Typhoid']
# pair:         ['Hepatitis C', 'Hepatitis E', 'Malaria']
# r
#
# RandomForest: ['Cervical spondylosis', 'Malaria']
# pair:         ['Fungal infection', 'Hepatitis B', 'Typhoid']
# r
#
# RandomForest: ['Jaundice', 'Urinary tract infection']
# pair:         ['AIDS', 'Varicose veins', 'vertigo Paroymsal  Positional Vertigo']
# r
#
# RandomForest: ['Malaria']
# pair:         ['Chicken pox', 'Hepatitis C']
# r
#
# RandomForest: ['Hypothyroidism', 'hepatitis A']
# pair:         ['Chronic cholestasis', 'Dengue', 'Jaundice']
# r
#
# RandomForest: ['Hepatitis D', 'Hypoglycemia']
# pair:         ['Acne', 'Hepatitis B', 'Osteoarthristis']
# r
#
# RandomForest: ['Chicken pox', 'Jaundice']
# pair:         ['Alcoholic hepatitis', 'Hyperthyroidism', 'Hypoglycemia']
# r
#
# RandomForest: ['Gastroenteritis', 'Hypothyroidism']
# pair:         ['Arthritis', 'Chicken pox', 'Peptic ulcer diseae']
# r
#
# RandomForest: ['Chicken pox', 'Common Cold']
# pair:         ['Cervical spondylosis', 'GERD', 'Paralysis (brain hemorrhage)']
# r
#
# RandomForest: ['Dimorphic hemmorhoids(piles)', 'Hepatitis D']
# pair:         ['Allergy', 'Arthritis', 'hepatitis A']
# r
#
# r 42 d 73 s 61
