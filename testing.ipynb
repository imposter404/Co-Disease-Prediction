# %%
import pandas as pd 
import numpy as np
import os
import random
import json

# %%
df = pd.read_csv("Training.csv")
disease=set(df['prognosis'])
disease=list(disease)
disease.sort()
final=[]

# %%
def Disease_symptom():
    sy={}
    for x in disease:
        sy[x]=[]
        for i in range(len(df)):
            if(df['prognosis'][i]==x):
                temp=[]
                for y in df.columns:
                    if(df[y][i]==1):
                        temp.append(y)
                temp.sort()
                sy[x].append(temp)

    #----------- save to csv file------------
    sy=json.dumps(sy)
    with open('a1.json','w+') as outfile:
        outfile.write(sy)

# %%
def Disease_symptom_duplicate():
    with open('a1.json','r') as openfile:
        df=json.load(openfile)

    for x in disease:
        df[x]=list(set(tuple(r) for r in df[x]))
    
    #----------- save to csv file------------
    df=json.dumps(df)
    with open('a2.json','w+') as outfile:
        outfile.write(df)

# %%
def Random_disease():
    global final
    final=[]
    for i in range(10000):
        m=random.randint(2,3)
        temp=[]
        for j in range(m):
            temp.append(disease[random.randint(0,len(disease)-1)])
        temp=list(set(temp))
        temp.sort()
        final.append(temp)
    print(final)
    #----------- save to json file------------
    final=json.dumps(final)
    with open('pair.json','w+') as outfile:
        outfile.write(final)

# %%
def make_Disease():
    final=[]
    f=[]
    with open('pair.json','r') as openfile:
        pair=json.load(openfile)
    with open('a2.json','r') as openfile:
        symptom=json.load(openfile)

    for i in range(len(pair)):
        temp=[]
        temp1=[]
        for j in range(len(pair[i])):
            l=random.randint(0,len(symptom[pair[i][j]])-1)
            # print(pair[i][j],l)
            temp.append(symptom[pair[i][j]][l])
            temp1+=symptom[pair[i][j]][l]
        final.append(temp)
        f.append(list(temp1))

    #----------- save to json file------------
    final=json.dumps(final)
    with open('a3.json','w+') as outfile:
        outfile.write(final)
    #----------------------------------------

    for i in range(len(f)):
        f[i]=set(f[i])
        f[i]=list(f[i])

    df = pd.read_csv("Training.csv")
    head=df.columns.to_list()
    z=[]
    for i in range(len(f)):
        binary=np.zeros(len(df.head(0).columns)-1,dtype=int)
        for j in range(len(f[i])):
            binary[head.index(f[i][j])]=1
        z.append(binary)

    # ----------- save to csv file------------
    df=pd.DataFrame(z)
    head.pop()
    print(head)
    df=df.set_axis(head,axis=1) 
    df.to_csv('a3_binary.csv',index=False)

# %%
# Disease_symptom()
# Disease_symptom_duplicate()

# %%
# Random_disease()
# make_Disease()
# Out:
# [['Hepatitis B', 'Impetigo', 'Peptic ulcer diseae'], ['Bronchial Asthma', 'Hypoglycemia', 'Tuberculosis'], ['Hepatitis B', 'Malaria'], ['Alcoholic hepatitis', 'Dengue', 'Dimorphic hemmorhoids(piles)'], ['Cervical spondylosis', 'Impetigo'], ['Alcoholic hepatitis', 'Varicose veins'], ['Diabetes', 'Impetigo', 'Osteoarthristis'], ['Bronchial Asthma', 'Peptic ulcer diseae'], ['Osteoarthristis', 'Varicose veins'], ['Drug Reaction', 'vertigo Paroymsal  Positional Vertigo'], ['Bronchial Asthma', 'Hepatitis B', 'Hypoglycemia'], ['Acne', 'Hepatitis D', 'Tuberculosis'], ['Cervical spondylosis', 'Drug Reaction', 'GERD'], ['Arthritis', 'Bronchial Asthma'], ['Dengue', 'Pneumonia', 'hepatitis A'], ['Diabetes', 'Impetigo', 'Malaria'], ['Tuberculosis', 'Varicose veins'], ['Chicken pox', 'Hypothyroidism'], ['Hepatitis D', 'Impetigo', 'Jaundice'], ['AIDS', 'Common Cold', 'Drug Reaction'], ['Bronchial Asthma', 'Hepatitis D', 'Malaria'], ['Hyperthyroidism', 'Osteoarthristis'], ['Chicken pox', 'Hypertension', 'Osteoarthristis'], ['Allergy', 'Dimorphic hemmorhoids(piles)', 'Hepatitis C'], ['Diabetes', 'Psoriasis'], ['Hypoglycemia', 'Tuberculosis', 'Urinary tract infection'], ['Drug Reaction', 'Hepatitis C', 'Migraine'], ['Chicken pox', 'Hepatitis B', 'Typhoid'], ['Peptic ulcer diseae', 'Pneumonia'], ['Allergy', 'Hepatitis D', 'Peptic ulcer diseae'], ['Hepatitis B', 'Hepatitis E', 'Malaria'], ['Heart attack', 'Hepatitis D'], ['Hepatitis E', 'Jaundice'], ['Dengue', 'Heart attack', 'Jaundice'], ['Migraine', 'Varicose veins'], ['Common Cold', 'Hepatitis B', 'Impetigo'], ['Cervical spondylosis', 'Typhoid'], ['Allergy', 'Drug Reaction', 'Tuberculosis'], ['Osteoarthristis', 'Peptic ulcer diseae'], ['Hypothyroidism', 'Paralysis (brain hemorrhage)', 'Tuberculosis'], ['Chronic cholestasis', 'Fungal infection', 'Hypertension'], ['AIDS', 'Osteoarthristis'], ['Alcoholic hepatitis', 'Fungal infection', 'Hypoglycemia'], ['Alcoholic hepatitis', 'Chronic cholestasis', 'GERD'], ['Bronchial Asthma', 'Cervical spondylosis', 'Jaundice'], ['Allergy', 'Migraine'], ['Diabetes', 'Gastroenteritis', 'Psoriasis'], ['Gastroenteritis', 'hepatitis A'], ['Paralysis (brain hemorrhage)', 'vertigo Paroymsal  Positional Vertigo'], ['Hepatitis C', 'Jaundice', 'Urinary tract infection'], ['Dengue', 'Impetigo'], ['Hypertension', 'Pneumonia', 'vertigo Paroymsal  Positional Vertigo'], ['Malaria', 'Typhoid'], ['Acne', 'Hepatitis E', 'Hypoglycemia'], ['Diabetes', 'GERD'], ['Common Cold', 'Hepatitis B', 'Pneumonia'], ['Hypertension', 'hepatitis A'], ['Fungal infection', 'Paralysis (brain hemorrhage)'], ['Drug Reaction', 'vertigo Paroymsal  Positional Vertigo'], ['AIDS', 'Chicken pox', 'Fungal infection'], ['Cervical spondylosis', 'Chronic cholestasis', 'Hypothyroidism'], ['Urinary tract infection', 'Varicose veins'], ['Alcoholic hepatitis', 'Common Cold'], ['Dengue', 'Hepatitis B', 'vertigo Paroymsal  Positional Vertigo'], ['Dengue', 'Heart attack', 'Hepatitis D'], ['Chronic cholestasis', 'Hepatitis E'], ['AIDS', 'Jaundice'], ['Dengue', 'Hypertension'], ['Arthritis', 'Hypoglycemia', 'Hypothyroidism'], ['Acne', 'Urinary tract infection'], ['Heart attack', 'Hepatitis C', 'Migraine'], ['Hepatitis C', 'Hypertension', 'Malaria'], ['Paralysis (brain hemorrhage)', 'Psoriasis'], ['Bronchial Asthma', 'Fungal infection', 'Hepatitis C'], ['Chicken pox', 'Diabetes', 'Fungal infection'], ['Heart attack', 'Osteoarthristis', 'Paralysis (brain hemorrhage)'], ['Cervical spondylosis', 'Chronic cholestasis', 'vertigo Paroymsal  Positional Vertigo'], ['Fungal infection', 'Varicose veins'], ['Dimorphic hemmorhoids(piles)', 'Hepatitis D'], ['Psoriasis', 'Tuberculosis'], ['Alcoholic hepatitis', 'vertigo Paroymsal  Positional Vertigo'], ['Allergy', 'Heart attack', 'Hepatitis E'], ['Hypertension', 'Jaundice', 'Paralysis (brain hemorrhage)'], ['Arthritis', 'Paralysis (brain hemorrhage)', 'Typhoid'], ['Dengue', 'Hyperthyroidism', 'Pneumonia'], ['Common Cold', 'Hepatitis E'], ['Acne', 'Osteoarthristis'], ['Migraine', 'T ...
# ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_ urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs', 'fast_heart_rate', 'pain_during_bowel_movements', 'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus', 'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity', 'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes', 'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties', 'excessive_hunger', 'extra_marital_contacts', 'drying_and_tingling_lips', 'slurred_speech', 'knee_pain', 'hip_joint_pain', 'muscle_weakness', 'stiff_neck', 'swelling_joints', 'movement_stiffness', 'spinning_movements', 'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side', 'loss_of_smell', 'bladder_discomfort', 'foul_smell_of urine', 'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching', 'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain', 'altered_sensorium', 'red_spots_over_body', 'belly_pain', 'abnormal_menstruation', 'dischromic _patches', 'watering_from_eyes', 'increased_appetite', 'polyuria', 'family_history', 'mucoid_sputum', 'rusty_sputum', 'lack_of_concentration', 'visual_disturbances', 'receiving_blood_transfusion', 'receiving_unsterile_injections', 'coma', 'stomach_bleeding', 'distention_of_abdomen', 'history_of_alcohol_consumption', 'fluid_overload.1', 'blood_in_sputum', 'prominent_veins_on_calf', 'palpitations', 'painful_walking', 'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'small_dents_in_nails', 'inflammatory_nails', 'blister', 'red_sore_around_nose', 'yellow_crust_ooze']

# %%
make_Disease()
# Out:
# ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_ urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs', 'fast_heart_rate', 'pain_during_bowel_movements', 'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus', 'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity', 'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes', 'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties', 'excessive_hunger', 'extra_marital_contacts', 'drying_and_tingling_lips', 'slurred_speech', 'knee_pain', 'hip_joint_pain', 'muscle_weakness', 'stiff_neck', 'swelling_joints', 'movement_stiffness', 'spinning_movements', 'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side', 'loss_of_smell', 'bladder_discomfort', 'foul_smell_of urine', 'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching', 'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain', 'altered_sensorium', 'red_spots_over_body', 'belly_pain', 'abnormal_menstruation', 'dischromic _patches', 'watering_from_eyes', 'increased_appetite', 'polyuria', 'family_history', 'mucoid_sputum', 'rusty_sputum', 'lack_of_concentration', 'visual_disturbances', 'receiving_blood_transfusion', 'receiving_unsterile_injections', 'coma', 'stomach_bleeding', 'distention_of_abdomen', 'history_of_alcohol_consumption', 'fluid_overload.1', 'blood_in_sputum', 'prominent_veins_on_calf', 'palpitations', 'painful_walking', 'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'small_dents_in_nails', 'inflammatory_nails', 'blister', 'red_sore_around_nose', 'yellow_crust_ooze']
