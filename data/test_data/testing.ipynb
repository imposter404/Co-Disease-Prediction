# %% [markdown]
# # Test Data

# %%
import pandas as pd 
import numpy as np
import os
import random
import json

# %% [markdown]
# Read Disease - Symptom Data

# %%
df = pd.read_csv("../Training.csv")
disease=set(df['prognosis'])
disease=list(disease)
disease.sort()
final=[]

# %% [markdown]
# Get All Disease With There Symptom

# %%
def Disease_symptom():
    sy={}
    for x in disease:
        sy[x]=[]
        for i in range(len(df)):
            if(df['prognosis'][i]==x):
                temp=[]
                for y in df.columns:
                    if(df[y][i]==1):
                        temp.append(y)
                temp.sort()
                sy[x].append(temp)

    #----------- save to csv file------------
    sy=json.dumps(sy)
    with open('a1.json','w+') as outfile:
        outfile.write(sy)

# %% [markdown]
# Remove Duplicate Disease Symptom

# %%
def Disease_symptom_duplicate():
    with open('a1.json','r') as openfile:
        df=json.load(openfile)

    for x in disease:
        df[x]=list(set(tuple(r) for r in df[x]))
    
    #----------- save to csv file------------
    df=json.dumps(df)
    with open('a2.json','w+') as outfile:
        outfile.write(df)

# %% [markdown]
# Make Random Disease Pair

# %%
def Random_disease():
    global final
    final=[]
    for i in range(10000):
        m=random.randint(2,3)
        temp=[]
        for j in range(m):
            temp.append(disease[random.randint(0,len(disease)-1)])
        temp=list(set(temp))
        temp.sort()
        final.append(temp)
    print(final)
    #----------- save to json file------------
    final=json.dumps(final)
    with open('pair.json','w+') as outfile:
        outfile.write(final)

# %% [markdown]
# Make Symptom From Disease Pair

# %%
def make_Disease():
    final=[]
    f=[]
    with open('test_pair.json','r') as openfile:
        pair=json.load(openfile)
    with open('a2.json','r') as openfile:
        symptom=json.load(openfile)

    for i in range(len(pair)):
        temp=[]
        temp1=[]
        for j in range(len(pair[i])):
            l=random.randint(0,len(symptom[pair[i][j]])-1)
            # print(pair[i][j],l)
            temp.append(symptom[pair[i][j]][l])
            temp1+=symptom[pair[i][j]][l]
        final.append(temp)
        f.append(list(temp1))

    #----------- save to json file------------
    final=json.dumps(final)
    with open('a3.json','w+') as outfile:
        outfile.write(final)
    #----------------------------------------

    for i in range(len(f)):
        f[i]=set(f[i])
        f[i]=list(f[i])

    df = pd.read_csv("../Training.csv")
    head=df.columns.to_list()
    z=[]
    for i in range(len(f)):
        binary=np.zeros(len(df.head(0).columns)-1,dtype=int)
        for j in range(len(f[i])):
            binary[head.index(f[i][j])]=1
        z.append(binary)

    # ----------- save to csv file------------
    df=pd.DataFrame(z)
    head.pop()
    print(head)
    df=df.set_axis(head,axis=1) 
    df.to_csv('a3_binary.csv',index=False)

# %% [markdown]
# Get Disease with Symptom

# %%
# only rum 1 time 
Disease_symptom()
Disease_symptom_duplicate()
#---------------------------

# %% [markdown]
# Make Random Disease

# %%
Random_disease()
make_Disease()
# Out:
# [['Cervical spondylosis', 'Malaria'], ['Acne', 'Allergy'], ['Heart attack', 'Hyperthyroidism', 'Urinary tract infection'], ['Dengue', 'Hepatitis B', 'Hypoglycemia'], ['Fungal infection', 'GERD'], ['Allergy', 'Drug Reaction', 'Pneumonia'], ['Arthritis', 'Hyperthyroidism'], ['Arthritis', 'Drug Reaction', 'Hepatitis E'], ['Hypertension', 'Psoriasis'], ['Dengue', 'Hypoglycemia'], ['Alcoholic hepatitis', 'Migraine', 'Pneumonia'], ['Bronchial Asthma', 'Chicken pox', 'Fungal infection'], ['Chicken pox', 'Diabetes', 'Typhoid'], ['Allergy', 'Hypertension'], ['Acne', 'Gastroenteritis'], ['Cervical spondylosis', 'Fungal infection', 'Pneumonia'], ['Acne', 'Paralysis (brain hemorrhage)'], ['Bronchial Asthma', 'Malaria', 'Osteoarthristis'], ['Heart attack', 'Paralysis (brain hemorrhage)', 'Psoriasis'], ['Hepatitis D', 'Hypoglycemia'], ['GERD', 'Psoriasis'], ['Fungal infection', 'Malaria'], ['Allergy', 'Gastroenteritis'], ['Bronchial Asthma', 'Varicose veins'], ['Dengue', 'Hypothyroidism', 'Osteoarthristis'], ['Common Cold', 'Diabetes', 'hepatitis A'], ['Drug Reaction', 'Varicose veins'], ['Cervical spondylosis', 'Jaundice', 'Osteoarthristis'], ['Hepatitis C', 'Hypoglycemia', 'Osteoarthristis'], ['Acne', 'Diabetes', 'Dimorphic hemmorhoids(piles)'], ['Hepatitis D', 'Paralysis (brain hemorrhage)', 'Peptic ulcer diseae'], ['AIDS', 'Chicken pox'], ['Common Cold', 'Hepatitis E', 'Impetigo'], ['Diabetes', 'Malaria'], ['Chicken pox', 'Peptic ulcer diseae', 'Typhoid'], ['Chicken pox', 'Fungal infection'], ['Chicken pox', 'Jaundice', 'hepatitis A'], ['Alcoholic hepatitis', 'Cervical spondylosis', 'Hypertension'], ['Cervical spondylosis', 'Chicken pox'], ['Chronic cholestasis', 'Hepatitis B', 'Osteoarthristis'], ['Dimorphic hemmorhoids(piles)', 'Hypertension', 'Malaria'], ['Dimorphic hemmorhoids(piles)', 'Drug Reaction'], ['Gastroenteritis', 'Migraine', 'Peptic ulcer diseae'], ['Malaria', 'Migraine', 'Osteoarthristis'], ['Arthritis', 'Chicken pox', 'Osteoarthristis'], ['Common Cold', 'Gastroenteritis', 'Osteoarthristis'], ['Hepatitis C', 'Peptic ulcer diseae'], ['Diabetes', 'Peptic ulcer diseae', 'Pneumonia'], ['Common Cold', 'Hypothyroidism'], ['Chronic cholestasis', 'Fungal infection', 'Hypoglycemia'], ['Dimorphic hemmorhoids(piles)', 'Psoriasis'], ['Cervical spondylosis', 'Chronic cholestasis'], ['Allergy', 'Chicken pox'], ['Alcoholic hepatitis', 'Common Cold', 'Hepatitis D'], ['Gastroenteritis', 'Hepatitis C', 'Hypothyroidism'], ['Arthritis', 'Hypoglycemia', 'Hypothyroidism'], ['GERD', 'Peptic ulcer diseae'], ['Acne', 'Malaria'], ['Allergy', 'Hypothyroidism', 'Migraine'], ['Bronchial Asthma', 'Fungal infection', 'Peptic ulcer diseae'], ['Acne', 'Cervical spondylosis', 'Pneumonia'], ['Bronchial Asthma', 'Chicken pox', 'Hypertension'], ['Fungal infection', 'Impetigo', 'Migraine'], ['Hypoglycemia', 'Impetigo'], ['Cervical spondylosis', 'Hepatitis D'], ['Acne', 'Migraine'], ['AIDS', 'Cervical spondylosis', 'Hypertension'], ['Hypothyroidism', 'Varicose veins'], ['Gastroenteritis', 'Hepatitis E'], ['GERD', 'Migraine'], ['Psoriasis', 'vertigo Paroymsal  Positional Vertigo'], ['Impetigo', 'Jaundice', 'Peptic ulcer diseae'], ['Drug Reaction', 'Fungal infection'], ['Chronic cholestasis', 'Hepatitis C', 'Peptic ulcer diseae'], ['Arthritis', 'Common Cold', 'Typhoid'], ['Chicken pox', 'Chronic cholestasis', 'Typhoid'], ['AIDS', 'Paralysis (brain hemorrhage)'], ['Arthritis', 'vertigo Paroymsal  Positional Vertigo'], ['Peptic ulcer diseae', 'Typhoid'], ['Fungal infection', 'Psoriasis', 'Urinary tract infection'], ['Arthritis', 'Chronic cholestasis'], ['Alcoholic hepatitis', 'Fungal infection', 'Hepatitis D'], ['Dimorphic hemmorhoids(piles)', 'Hepatitis E', 'Hypertension'], ['Common Cold', 'Hypoglycemia'], ['Dengue', 'Hepatitis C'], ['Allergy', 'Fungal infection', 'Hepatitis E'], ['Hypoglycemia', 'Impetigo', 'Psoriasis'], ['Chicken pox', 'Impetigo', 'Typhoid'], ['Heart attack', 'Osteoarthristis'], ['Gastroenteritis', 'Malaria', 'Psoriasis'], ['Bronchial Asthma',  ...
# ['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing', 'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting', 'vomiting', 'burning_micturition', 'spotting_ urination', 'fatigue', 'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings', 'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat', 'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes', 'breathlessness', 'sweating', 'dehydration', 'indigestion', 'headache', 'yellowish_skin', 'dark_urine', 'nausea', 'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain', 'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever', 'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure', 'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes', 'malaise', 'blurred_and_distorted_vision', 'phlegm', 'throat_irritation', 'redness_of_eyes', 'sinus_pressure', 'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs', 'fast_heart_rate', 'pain_during_bowel_movements', 'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus', 'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity', 'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes', 'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties', 'excessive_hunger', 'extra_marital_contacts', 'drying_and_tingling_lips', 'slurred_speech', 'knee_pain', 'hip_joint_pain', 'muscle_weakness', 'stiff_neck', 'swelling_joints', 'movement_stiffness', 'spinning_movements', 'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side', 'loss_of_smell', 'bladder_discomfort', 'foul_smell_of urine', 'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching', 'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain', 'altered_sensorium', 'red_spots_over_body', 'belly_pain', 'abnormal_menstruation', 'dischromic _patches', 'watering_from_eyes', 'increased_appetite', 'polyuria', 'family_history', 'mucoid_sputum', 'rusty_sputum', 'lack_of_concentration', 'visual_disturbances', 'receiving_blood_transfusion', 'receiving_unsterile_injections', 'coma', 'stomach_bleeding', 'distention_of_abdomen', 'history_of_alcohol_consumption', 'fluid_overload.1', 'blood_in_sputum', 'prominent_veins_on_calf', 'palpitations', 'painful_walking', 'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting', 'small_dents_in_nails', 'inflammatory_nails', 'blister', 'red_sore_around_nose', 'yellow_crust_ooze']
